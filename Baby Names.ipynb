# %%
import numpy as np
import matplotlib.pyplot as pp
import pandas as pd
import seaborn
import zipfile
import os

# %%
# %matplotlib inline

# %%
zipfile.ZipFile('names.zip').extractall('.')

# %%
os.listdir('.')
# Out:
# ['.ipynb_checkpoints',
#  '__MACOSX',
#  'Baby Names.ipynb',
#  'hello.py',
#  'myFirst.py',
#  'names',
#  'names.zip']

# %%
os.listdir('names')
# Out:
# ['NationalReadMe.pdf',
#  'yob1880.txt',
#  'yob1881.txt',
#  'yob1882.txt',
#  'yob1883.txt',
#  'yob1884.txt',
#  'yob1885.txt',
#  'yob1886.txt',
#  'yob1887.txt',
#  'yob1888.txt',
#  'yob1889.txt',
#  'yob1890.txt',
#  'yob1891.txt',
#  'yob1892.txt',
#  'yob1893.txt',
#  'yob1894.txt',
#  'yob1895.txt',
#  'yob1896.txt',
#  'yob1897.txt',
#  'yob1898.txt',
#  'yob1899.txt',
#  'yob1900.txt',
#  'yob1901.txt',
#  'yob1902.txt',
#  'yob1903.txt',
#  'yob1904.txt',
#  'yob1905.txt',
#  'yob1906.txt',
#  'yob1907.txt',
#  'yob1908.txt',
#  'yob1909.txt',
#  'yob1910.txt',
#  'yob1911.txt',
#  'yob1912.txt',
#  'yob1913.txt',
#  'yob1914.txt',
#  'yob1915.txt',
#  'yob1916.txt',
#  'yob1917.txt',
#  'yob1918.txt',
#  'yob1919.txt',
#  'yob1920.txt',
#  'yob1921.txt',
#  'yob1922.txt',
#  'yob1923.txt',
#  'yob1924.txt',
#  'yob1925.txt',
#  'yob1926.txt',
#  'yob1927.txt',
#  'yob1928.txt',
#  'yob1929.txt',
#  'yob1930.txt',
#  'yob1931.txt',
#  'yob1932.txt',
#  'yob1933.txt',
# ...

# %%
open('names/yob1996.txt').readlines()
# Out:
# ['Emily,F,25149\r\n',
#  'Jessica,F,24191\r\n',
#  'Ashley,F,23675\r\n',
#  'Sarah,F,21025\r\n',
#  'Samantha,F,20545\r\n',
#  'Taylor,F,19151\r\n',
#  'Hannah,F,18593\r\n',
#  'Alexis,F,16587\r\n',
#  'Rachel,F,16109\r\n',
#  'Elizabeth,F,15990\r\n',
#  'Kayla,F,15270\r\n',
#  'Megan,F,14767\r\n',
#  'Amanda,F,13969\r\n',
#  'Brittany,F,13796\r\n',
#  'Madison,F,13410\r\n',
#  'Lauren,F,12596\r\n',
#  'Brianna,F,11923\r\n',
#  'Victoria,F,11856\r\n',
#  'Jennifer,F,11728\r\n',
#  'Stephanie,F,11639\r\n',
#  'Courtney,F,11343\r\n',
#  'Nicole,F,11132\r\n',
#  'Alyssa,F,11021\r\n',
#  'Rebecca,F,10620\r\n',
#  'Morgan,F,10291\r\n',
#  'Alexandra,F,10021\r\n',
#  'Amber,F,9770\r\n',
#  'Jasmine,F,9706\r\n',
#  'Danielle,F,9284\r\n',
#  'Haley,F,9040\r\n',
#  'Katherine,F,8873\r\n',
#  'Abigail,F,8598\r\n',
#  'Anna,F,8552\r\n',
#  'Olivia,F,8122\r\n',
#  'Shelby,F,7949\r\n',
#  'Kelsey,F,7655\r\n',
#  'Maria,F,7593\r\n',
#  'Allison,F,7453\r\n',
#  'Sydney,F,7258\r\n',
# ...

# %%
open('names/yob1998.txt').readlines()[:10]
# Out:
# ['Emily,F,26179\r\n',
#  'Hannah,F,21371\r\n',
#  'Samantha,F,20191\r\n',
#  'Sarah,F,19870\r\n',
#  'Ashley,F,19869\r\n',
#  'Alexis,F,19777\r\n',
#  'Taylor,F,18572\r\n',
#  'Jessica,F,18231\r\n',
#  'Madison,F,17786\r\n',
#  'Elizabeth,F,15178\r\n']

# %%
names2011 = pd.read_csv('names/yob2011.txt')

# %%
names2011.head()
# Out:
#      Sophia  F  21816
# 0  Isabella  F  19870
# 1      Emma  F  18777
# 2    Olivia  F  17294
# 3       Ava  F  15480
# 4     Emily  F  14236

# %%
names2011 = pd.read_csv('names/yob2011.txt',names=['Name',"Sex",'Number'])

# %%
names2011.head()
# Out:
#        Name Sex  Number
# 0    Sophia   F   21816
# 1  Isabella   F   19870
# 2      Emma   F   18777
# 3    Olivia   F   17294
# 4       Ava   F   15480

# %%
names_all = []

# %%
print names_all
# Out:
# []

# %%
for year in range(1880,2014+1):
    print year
# Out:
# 1880
# 1881
# 1882
# 1883
# 1884
# 1885
# 1886
# 1887
# 1888
# 1889
# 1890
# 1891
# 1892
# 1893
# 1894
# 1895
# 1896
# 1897
# 1898
# 1899
# 1900
# 1901
# 1902
# 1903
# 1904
# 1905
# 1906
# 1907
# 1908
# 1909
# 1910
# 1911
# 1912
# 1913
# 1914
# 1915
# 1916
# 1917
# 1918
# 1919
# 1920
# 1921
# 1922
# 1923
# 1924
# 1925
# 1926
# 1927
# 1928
# 1929
# 1930
# 1931
# 1932
# 1933
# 1934
# 1935
# 1936
# 1937
# 1938
# 1939
# 1940
# 1941
# 1942
# 1943
# 1944
# 1945
# 1946
# 1947
# 1948
# 1949
# 1950
# 1951
# 1952
# 1953
# 1954
# 1955
# 1956
# 1957
# 1958
# 1959
# 1960
# 1961
# 1962
# 1963
# 1964
# 1965
# 1966
# 1967
# 1968
# 1969
# 1970
# 1971
# 1972
# 1973
# 1974
# 1975
# 1976
# 1977
# 1978
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014

# %%
for year in range(1880,2014+1):
    names_all.append(pd.read_csv('names/yob{}.txt'.format(year),names=['Name','Sex','Number']))

# %%
names_all.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-403e42352faa> in <module>()
# ----> 1 names_all.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
names_all[:10]
# Out:
# [           Name Sex  Number
#  0          Mary   F    7065
#  1          Anna   F    2604
#  2          Emma   F    2003
#  3     Elizabeth   F    1939
#  4        Minnie   F    1746
#  5      Margaret   F    1578
#  6           Ida   F    1472
#  7         Alice   F    1414
#  8        Bertha   F    1320
#  9         Sarah   F    1288
#  10        Annie   F    1258
#  11        Clara   F    1226
#  12         Ella   F    1156
#  13     Florence   F    1063
#  14         Cora   F    1045
#  15       Martha   F    1040
#  16        Laura   F    1012
#  17       Nellie   F     995
#  18        Grace   F     982
#  19       Carrie   F     949
#  20        Maude   F     858
#  21        Mabel   F     808
#  22       Bessie   F     796
#  23       Jennie   F     793
#  24     Gertrude   F     787
#  25        Julia   F     783
#  26       Hattie   F     769
#  27        Edith   F     768
#  28       Mattie   F     704
#  29         Rose   F     700
#  ...         ...  ..     ...
# ...

# %%
names_all = []
for year in (1880,2014+1):
    names_all.append(pd.read_csv('names/yob{}.txt'.format(year),names=['name','sex','number']))
    names_all[-1]['year'] = year
    
allyears = pd.concat(names_all)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-18-330990eab313> in <module>()
#       1 names_all = []
#       2 for year in (1880,2014+1):
# ----> 3     names_all.append(pd.read_csv('names/yob{}.txt'.format(year),names=['name','sex','number']))
#       4     names_all[-1]['year'] = year
#       5
#
# ...

# %%
names_all = []
for year in range(1880,2014+1):
    names_all.append(pd.read_csv('names/yob{}.txt'.format(year),names=['name','sex','number']))
    names_all[-1]['year'] = year
    
allyears = pd.concat(names_all)

# %%
allyears[:10]
# Out:
#         name sex  number  year
# 0       Mary   F    7065  1880
# 1       Anna   F    2604  1880
# 2       Emma   F    2003  1880
# 3  Elizabeth   F    1939  1880
# 4     Minnie   F    1746  1880
# 5   Margaret   F    1578  1880
# 6        Ida   F    1472  1880
# 7      Alice   F    1414  1880
# 8     Bertha   F    1320  1880
# 9      Sarah   F    1288  1880

# %%
allyears.head()
# Out:
#         name sex  number  year
# 0       Mary   F    7065  1880
# 1       Anna   F    2604  1880
# 2       Emma   F    2003  1880
# 3  Elizabeth   F    1939  1880
# 4     Minnie   F    1746  1880

# %%
allyears.tail()
# Out:
#           name sex  number  year
# 33039   Zykeem   M       5  2014
# 33040   Zymeer   M       5  2014
# 33041  Zymiere   M       5  2014
# 33042    Zyran   M       5  2014
# 33043    Zyrin   M       5  2014

# %%
names_all.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-403e42352faa> in <module>()
# ----> 1 names_all.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
print names_all
# Out:
# [           name sex  number  year
# 0          Mary   F    7065  1880
# 1          Anna   F    2604  1880
# 2          Emma   F    2003  1880
# 3     Elizabeth   F    1939  1880
# 4        Minnie   F    1746  1880
# 5      Margaret   F    1578  1880
# 6           Ida   F    1472  1880
# 7         Alice   F    1414  1880
# 8        Bertha   F    1320  1880
# 9         Sarah   F    1288  1880
# 10        Annie   F    1258  1880
# 11        Clara   F    1226  1880
# 12         Ella   F    1156  1880
# 13     Florence   F    1063  1880
# 14         Cora   F    1045  1880
# 15       Martha   F    1040  1880
# 16        Laura   F    1012  1880
# 17       Nellie   F     995  1880
# 18        Grace   F     982  1880
# 19       Carrie   F     949  1880
# 20        Maude   F     858  1880
# 21        Mabel   F     808  1880
# 22       Bessie   F     796  1880
# 23       Jennie   F     793  1880
# 24     Gertrude   F     787  1880
# 25        Julia   F     783  1880
# ...

# %%
allyears_indexed = allyears.set_index(['sex','name','year']).sort_index()

# %%
allyears_indexed.head()
# Out:
#                     number
# sex name      year
# F   Aabha     2011       7
#               2012       5
#               2014       9
#     Aabriella 2008       5
#               2014       5

# %%
allyears_indexed
# Out:
#                     number
# sex name      year
# F   Aabha     2014       9
#     Aabriella 2014       5
#     Aadhira   2014      13
#     Aadhya    2014     249
#     Aaditri   2014      10
#     Aadrika   2014       5
#     Aadvika   2014       7
#     Aadya     2014     164
#     Aahana    2014      59
#     Aahna     2014      21
#     Aaila     2014      12
#     Aailyah   2014       8
#     Aaima     2014      12
#     Aaira     2014      26
#     Aairah    2014      10
#     Aaiza     2014       5
#     Aakriti   2014       9
#     Aala      2014       9
#     Aalaiyah  2014       6
#     Aalana    2014       6
#     Aalanah   2014       6
#     Aalani    2014       9
#     Aalaya    2014      13
#     Aalayah   2014      67
#     Aalayna   2014       9
#     Aalaysia  2014      12
#     Aaleah    2014      24
#     Aaleahya  2014       7
#     Aaleeyah  2014      11
#     Aaleigha  2014       8
# ...                    ...
# M   Zyire     2014      15
# ...

# %%
allyears.head()
# Out:
#         name sex  number  year
# 0       Mary   F    7065  1880
# 1       Anna   F    2604  1880
# 2       Emma   F    2003  1880
# 3  Elizabeth   F    1939  1880
# 4     Minnie   F    1746  1880

# %%
allyears_indexed
# Out:
#                     number
# sex name      year
# F   Aabha     2011       7
#               2012       5
#               2014       9
#     Aabriella 2008       5
#               2014       5
#     Aaden     2009       5
#     Aadhira   2012       6
#               2013      10
#               2014      13
#     Aadhya    2007      10
#               2008       9
#               2009      18
#               2010      19
#               2011      52
#               2012     110
#               2013     172
#               2014     249
#     Aadi      2006       5
#               2012       5
#               2013       6
#     Aadison   2009       6
#               2012       5
#     Aaditri   2010       5
#               2012       5
#               2013       6
#               2014      10
#     Aadrika   2013       5
#               2014       5
#     Aadvika   2013       6
#               2014       7
# ...                    ...
# M   Zyshawn   2008      14
# ...

# %%
allyears_indexed.loc['F','Mary']
# Out:
#       number
# year
# 1880    7065
# 1881    6919
# 1882    8148
# 1883    8012
# 1884    9217
# 1885    9128
# 1886    9890
# 1887    9888
# 1888   11754
# 1889   11648
# 1890   12078
# 1891   11703
# 1892   13173
# 1893   12784
# 1894   13151
# 1895   13446
# 1896   13811
# 1897   13413
# 1898   14406
# 1899   13172
# 1900   16707
# 1901   13136
# 1902   14486
# 1903   14275
# 1904   14962
# 1905   16067
# 1906   16370
# 1907   17580
# 1908   18666
# 1909   19259
# ...      ...
# 1985    9239
# 1986    8503
# 1987    8395
# 1988    8508
# 1989    8642
# 1990    8664
# 1991    8756
# 1992    8452
# 1993    8110
# 1994    7746
# 1995    7433
# 1996    6942
# 1997    6626
# 1998    6429
# 1999    6359
# 2000    6182
# 2001    5724
# 2002    5450
# 2003    5009
# 2004    4803
# 2005    4447
# 2006    4081
# 2007    3673
# 2008    3490
# 2009    3154
# 2010    2862
# 2011    2701
# 2012    2565
# 2013    2632
# 2014    2611
#
# [135 rows x 1 columns]

# %%
def plotname(sex,name):
    data = allyears_indexed.loc[sex,name]
    pp.plot(data.index,data.values)

# %%
plotname('F','Mary')

# %%
plotname('f','Mary')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-3e91aa20d6e9> in <module>()
# ----> 1 plotname('f','Mary')
#
# <ipython-input-39-becc6c020c40> in plotname(sex, name)
#       1 def plotname(sex,name):
# ----> 2     data = allyears_indexed.loc[sex,name]
#       3     pp.plot(data.index,data.values)
#
# /Users/vaibhavyadav/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1323             except (KeyError, IndexError):
#    1324                 pass
# -> 1325             return self._getitem_tuple(key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
#
# /Users/vaibhavyadav/anaconda2/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#     834     def _getitem_tuple(self, tup):
#     835         try:
# ...

# %%
pp.figure(figsize=(12,12.5))
names = ['Michael','John','David','Tony']
for name in names:
    plotname('M',name)
    
pp.legend(names)

# %%
variants = allyears_indexed.loc['F'].loc[names].unstack(level=0).fillna(0)

# %%
pp.stackplot(variants.index,variants.values.T)

# %%
allyears_indexed.loc['M',:,2008].sort('number', ascending=False).head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-12f9241c3624> in <module>()
# ----> 1 allyears_indexed.loc['M',:,2008].sort('number', ascending=False).head()
#
# /Users/vaibhavyadav/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'
